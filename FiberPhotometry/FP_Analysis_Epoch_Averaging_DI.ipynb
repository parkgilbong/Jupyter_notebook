# %% [markdown]
# ## FP Analysis - Epoch Averaging for Direct Interaction Test
# 1. Date: Recording - 2024/06/21-22, Analysis - 2024/06/27-
# 2. Task: Direct interaction test (habituation(HA), direct interaction(DI) sessions)
# 3. Performer: Recording - YGKim, Analysis - YGKim
# 4. Animal: PV-Cre female mice
# 5. Group, ID: as follows

# %% [markdown]
# ### 0. Import libraries

# %%
# import the libraries that we will use
import os
import pandas as pd
import numpy as  np
import pylab as plt
import seaborn as sns
from matplotlib.patches import Patch
from scipy.signal import medfilt, butter, filtfilt, find_peaks
from scipy.stats import linregress, f_oneway, ttest_ind 
from scipy.optimize import curve_fit, minimize
from sklearn.metrics import roc_auc_score
from scipy.integrate import simps, trapz
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib 
matplotlib.rcParams['font.size'] = 15 #set font size for all plots

# %% [markdown]
# ### 1. Set file parameters and working dir
# Put everything that should be sepecified by user.

# %%
Base_folder = r'C:/Users/YGKim_IBS/Documents/GitHub/Jupyter_notebook/FiberPhotometry' 
Batch_folder = '240620_PV-Cre' 
Animal_ID = 'PV_F_G01_003'
Session = 'DI'

FPS = 25 #Frame per second of behavior data
Duration_sec = 600 #Recording duration of behavior data
SavePlots = False
SaveData = False

# %% [markdown]
# Set working directory

# %%
cwd = os.path.join(Base_folder, Batch_folder, Animal_ID, Session)
if not os.path.exists(cwd):
        os.makedirs(cwd)
os.chdir(cwd)
os.getcwd()
# Out:
# 'C:\\Users\\YGKim_IBS\\Documents\\GitHub\\Jupyter_notebook\\FiberPhotometry\\240620_PV-Cre\\PV_F_G01_003\\DI'

# %% [markdown]
# ### 2. Load data-sets

# %%
#Load preprocessed data from Fiber photometry recording
GCaMP_signal = pd.read_pickle(os.path.join(os.getcwd(),"Final_table.pkl"))
time_sec = GCaMP_signal.time
signal_dF_F = GCaMP_signal.value
GCaMP_signal.head()
# Out:
#    original_time      time     value
# 0       6.771179  0.000328 -3.156383
# 1       6.772162  0.001311 -3.151007
# 2       6.773145  0.002294 -3.145609
# 3       6.774129  0.003277 -3.140188
# 4       6.775112  0.004260 -3.134745

# %%
#Load postprocessed data from DeepLabCut analysis or manual scoring
df_EVT = pd.read_csv('EVT4DI_241204_2.csv', header=0, index_col=0)
df_EVT.head()
# Out:
#    EVT1  EVT2  EVT3  EVT4  EVT5  EVT6  EVT7
# 0   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ### 3. Analysis & Statistical testing

# %% [markdown]
# #### 2-1. Peak detection
# To detect peaks in the recorded signals, we will use find_peaks function in scipy.singal module which was already imported in our environment at the beginning. This function finds peaks inside a signal based on peak properties. For a successful peak detection, several parameters, such as height, threshold, distance, prominence, and width, should be specified by users.

# %%
# Find peaks in the dFF signal using the scipy.signal.find_peaks() function
peaks, _ =find_peaks(x=signal_dF_F, prominence=4) #The prominence can be either 2 or 4.  
PeakNum = len(peaks)

# Function to find onset of the peak
def find_peak_onset(signal, peak_index, threshold=0.0005):
    onset_index = peak_index
    while onset_index > 0 and signal[onset_index] > signal[onset_index - 1] - threshold:
        onset_index -= 1
    return onset_index

# Find onset times for all peaks
onset_indices = [find_peak_onset(signal_dF_F, peak) for peak in peaks]

fig1 = plt.figure(figsize=(20,12))
ax1=fig1.add_subplot(311)
plot1=ax1.plot(time_sec, signal_dF_F, 'g', label='GCaMP dF/F')
Peaks = ax1.plot(time_sec[peaks], signal_dF_F[peaks], label = 'peaks', color = 'r', marker='o', ls ='')
Onsets = ax1.plot(time_sec[onset_indices], signal_dF_F[onset_indices], label='onsets', color = 'm', marker ='o', ls = "")

# ax1.set_ylim(-10, 15)
ax1.set_xlabel('Time (seconds)')
ax1.set_ylabel('GCaMP dF/F (%)', color='g')
ax1.set_title('Peak detection')
# ax1.set_xlim(600, 610) # 초단위로 입력하여 x-axis zoom in 가능 

lines = plot1 + Peaks + Onsets
labels = [l.get_label() for l in lines]  #get legend labels
legend = ax1.legend(lines, labels, loc='upper right', bbox_to_anchor=(1, 1)) #add legend

fig1.tight_layout()

if SavePlots == True:
    plt.savefig('Plot_Peak_detection.png')

# %%
# detected peaks에 대한 정보를 DataFrame으로 저장 
df_peaks = pd.DataFrame(data={'Peak_Index': peaks,
                              'Peak_X': np.array(time_sec[peaks]), 
                              'Peak_Y': np.array(signal_dF_F[peaks]),
                              'FrameForPeak': np.int64((time_sec[peaks])*FPS),
                              'Onset_Index': np.array(onset_indices),
                              'Onset_X': np.array(time_sec[onset_indices]),
                              'Onset_Y': np.array(signal_dF_F[onset_indices]),
                              'FrameForOnset': np.int64((time_sec[onset_indices])*FPS),
                              'OnsetLatency': np.subtract(np.array(time_sec[peaks]), np.array(time_sec[onset_indices])),
                              'Height': np.subtract(np.array(signal_dF_F[peaks]), np.array(signal_dF_F[onset_indices]))})

if SaveData == True:
    df_peaks.to_csv('Data_Peak_detection.csv', header=True)

df_peaks

# %% [markdown]
# #### 2-2. Epoch averaging

# %% [markdown]
# ##### EVT1 Epoch averaging
# The EVT1 is defined as a nose-poke event. To identify Nose-poke events, the nose of the subject animal and snout of the stimulus animal should be labeled correctly first. Then, three criteria were used. The distance between the nose and snout should be less than 30 pixels. In addition, Nose-poke event should have at least a minute-long duration. lastly, a valid nose-poke event should be aparted at least 2 seconds from the previous event.

# %%
# Generate time series of behavioral data
CamTickTime = np.linspace(0, Duration_sec, Duration_sec*FPS)

# First make a continous time series of social events
# Event1 index == 1이면 Nose-to-Nose interaction ON, Event1 index == 2이면 Nose-to-Nose interaction OFF.
if 'EVT1' in df_EVT.columns: 
    Nose2Nose_ON = np.array(CamTickTime[df_EVT.EVT1 == 1])
    Nose2Nose_OFF = np.array(CamTickTime[df_EVT.EVT1 == 2])

# Event2_index == 1이면 Nose-to-Body interaction ON, EVT2 == 2이면 Nose-to-Body interaction OFF. 
Nose2Body_ON = np.array(CamTickTime[df_EVT.EVT2 == 1]) 
# S_zone_in = np.insert(S_zone_in,0,CamTick[0]) #혹시 처음부터 S_zone에서 시작할 경우 Frame0의 EVT2 index를 임의로 조정.
Nose2Body_OFF = np.array(CamTickTime[df_EVT.EVT2 == 2]) 

# Event3_index == 1이면 Nose-to-Anogenital interaction ON, EVT2 == 2이면 Nose-to-Anogenital interaction OFF.
Nose2Anogenital_ON = np.array(CamTickTime[df_EVT.EVT3 == 1])
Nose2Anogenital_OFF = np.array(CamTickTime[df_EVT.EVT3 == 2])

# Event4_index == 1이면 Body-to-Nose ON, EVT2 == 2이면 Body-to-Nose OFF.
Body2Nose_ON = np.array(CamTickTime[df_EVT.EVT4 == 1])
Body2Nose_OFF = np.array(CamTickTime[df_EVT.EVT4 == 2])

# Event5_index == 1이면 Anogenital-to-Nose interaction ON, EVT2 == 2이면 Anogenital-to-Nose interaction OFF.
Anogenital2Nose_ON = np.array(CamTickTime[df_EVT.EVT5 == 1])
Anogenital2Nose_OFF = np.array(CamTickTime[df_EVT.EVT5 == 2])

# Event6_index == 1이면 Side-by-Side ON, EVT2 == 2이면 Side-by-Side OFF.
SideBySide_ON = np.array(CamTickTime[df_EVT.EVT6 == 1])
SideBySide_OFF = np.array(CamTickTime[df_EVT.EVT6 == 2])

# Event7_index == 1이면 Side-reverse-Side ON, EVT2 == 2이면 Side-reverse-Side OFF.
SideReverseSide_ON = np.array(CamTickTime[df_EVT.EVT7 == 1])
SideReverseSide_OFF = np.array(CamTickTime[df_EVT.EVT7 == 2])

# %%
Evt_x = np.append(np.append(time_sec[0], np.reshape(np.kron([Nose2Nose_ON, Nose2Nose_OFF],
                   np.array([[1], [1]])).T, [1,-1])[0]), np.array(time_sec)[-1])
sz = len(Nose2Nose_ON)

CamTick = []

for i in range(len(Nose2Nose_ON)):
    CamTick.append(1)

# Create a vertical stack of arrays: two arrays of zeros('np.zeros(sz)') and two arrays of ones (d')
# Then, transpose the stacked array and reshaping it. 
# Append '0' at the start and end of the reshaped array
Evt_y = np.append(np.append(0, np.reshape(np.vstack([np.zeros(sz), CamTick, CamTick, np.zeros(sz)]).T, [1, -1])[0]), 0)

y_scale = 3
y_offset = -8

# %%
# First subplot in a series: dFF with social epocs
fig3 = plt.figure(figsize=(10,6))
ax2 = fig3.add_subplot(211)

p1, = ax2.plot(time_sec, signal_dF_F, label='GCaMP', linewidth=1, color='green')
p2, = ax2.plot(Evt_x, y_scale*Evt_y+y_offset, linewidth=1, color='dodgerblue', label='Nose-to-Nose')
ax2.set_ylim(-10, 10)
ax2.set_xlim(0, 600)
ax2.set_ylabel(r'$\Delta$F/F (%)')
ax2.set_xlabel('Time (sec)')
ax2.set_title('dFF when Nose-to-Nose Interaction')
ax2.legend(handles=[p1,p2], loc='lower right', bbox_to_anchor=(1, 1))
fig3.tight_layout()

# %%
# 선택한 이벤트
EVTtype = 'EVT1'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines = []  

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
    selected_event_time = row['EVT_time']

    # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출
    start_time = selected_event_time - 5
    end_time = selected_event_time + 10
    filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]

    # 시간을 조정하여 데이터 시점을 맞춤
    filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고 
    filtered_data['time'] -= selected_event_time

    # lineplot 그리기 (투명도를 조절하여 녹색으로 표시)
    x_data = filtered_data['time']
    y_data = filtered_data['value']
    
    line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
    all_lines.append(y_data.values)  # 각 시점에서의 데이터들을 저장
    start_time_list.append(start_time)
    end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines = pd.DataFrame(all_lines)
data = all_lines.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data, axis=0)
std_values = np.nanstd(data, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.ylim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:
    all_lines.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl')
    df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')


# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True: 
    plt.savefig(f'Plot_epoch_averaging_{EVTtype}_Mean+SD.png')

# Show the plot
plt.show()

# %%
# Create the plot
# fig3 = plt.figure(figsize=(10,6))
ax3 = fig3.add_subplot(212)

# Create the line plot
p1, = ax3.plot(time_sec, signal_dF_F,linewidth=1, color='green', label='GCaMP')

# Add the vertical spnas using 'axvspan'.
for on, off in zip(Nose2Body_ON, Nose2Body_OFF):
    ax3.axvspan(on, off, alpha=0.3, color='red')
for on, off in zip(Nose2Anogenital_ON, Nose2Anogenital_OFF):
    ax3.axvspan(on, off, alpha=0.3, color='orange')
for on, off in zip(Body2Nose_ON, Body2Nose_OFF):
    ax3.axvspan(on, off, alpha=0.3, color='yellow')
for on, off in zip(Anogenital2Nose_ON, Anogenital2Nose_OFF):
    ax3.axvspan(on, off, alpha=0.3, color='blue')
ax3.set_ylim(-5, 10)
ax3.set_ylim(-5, 10)
ax3.set_ylim(-5, 10)
ax3.set_xlim(0, 600)
ax3.set_ylabel(r'$\Delta$F/F (%)')
ax3.set_xlabel('Time (sec)')
ax3.set_title('dFF with other behaviors')

# Create a custom legend for the vertical spans. 
handles, labels = ax3.get_legend_handles_labels()
handles.append(Patch(color='red', alpha=0.3, label='Nose-to-Body'))
handles.append(Patch(color='orange', alpha=0.3, label='Nose-to-Anogenital'))
handles.append(Patch(color='yellow', alpha=0.3, label='Body-to-Nose'))
handles.append(Patch(color='blue', alpha=0.3, label='Anogenital-to-Nose'))

ax3.legend(handles=handles, loc='lower right',bbox_to_anchor=(1, 1))

fig3.tight_layout()

if SavePlots == True: 
    plt.savefig('Plot_dFF_with_behavior_segmentation.png')

fig3

# %%
# 선택한 이벤트
EVTtype = 'EVT2'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines2 = [] 

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []


# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
    selected_event_time = row['EVT_time']

    # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출
    start_time = selected_event_time - 5
    end_time = selected_event_time + 10
    filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]

    # 시간을 조정하여 데이터 시점을 맞춤
    filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고 
    filtered_data['time'] -= selected_event_time

    # lineplot 그리기 (투명도를 조절하여 녹색으로 표시)
    x_data = filtered_data['time']
    y_data = filtered_data['value']
    
    line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
    all_lines2.append(y_data.values)  # 각 시점에서의 데이터들을 저장
    start_time_list.append(start_time)
    end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines2 = pd.DataFrame(all_lines2)
data2 = all_lines2.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data2, axis=0)
std_values = np.nanstd(data2, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:
    all_lines2.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl')
    df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')
    



# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)


if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
# 선택한 이벤트
EVTtype = 'EVT3'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines3 = []  

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
    selected_event_time = row['EVT_time']

    # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출
    start_time = selected_event_time - 5
    end_time = selected_event_time + 10
    filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]

    # 시간을 조정하여 데이터 시점을 맞춤
    filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고 
    filtered_data['time'] -= selected_event_time

    # lineplot 그리기 (투명도를 조절하여 녹색으로 표시)
    x_data = filtered_data['time']
    y_data = filtered_data['value']
    
    line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
    all_lines3.append(y_data.values)  # 각 시점에서의 데이터들을 저장
    start_time_list.append(start_time)
    end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines3 = pd.DataFrame(all_lines3)
data3 = all_lines3.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data3, axis=0)
std_values = np.nanstd(data3, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:
    all_lines3.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl')
    df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')

# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
# 선택한 이벤트
EVTtype = 'EVT4'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines4 = [] 

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
    selected_event_time = row['EVT_time']

    # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출
    start_time = selected_event_time - 5
    end_time = selected_event_time + 10
    filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]

    # 시간을 조정하여 데이터 시점을 맞춤
    filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고 
    filtered_data['time'] -= selected_event_time

    # lineplot 그리기 (투명도를 조절하여 녹색으로 표시)
    x_data = filtered_data['time']
    y_data = filtered_data['value']
    
    line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
    all_lines4.append(y_data.values)  # 각 시점에서의 데이터들을 저장
    start_time_list.append(start_time)
    end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines4 = pd.DataFrame(all_lines4)
data4 = all_lines4.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data4, axis=0)
std_values = np.nanstd(data4, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:
    all_lines4.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl')
    df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')

# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
    # 선택한 이벤트
EVTtype = 'EVT5'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines5 = [] 

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
     selected_event_time = row['EVT_time']
     
     # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출 
     start_time = selected_event_time - 5
     end_time = selected_event_time + 10 
     filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]
     
     # 시간을 조정하여 데이터 시점을 맞춤 
     filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고  
     filtered_data['time'] -= selected_event_time 
     
     # lineplot 그리기 (투명도를 조절하여 녹색으로 표시) 
     x_data = filtered_data['time'] 
     y_data = filtered_data['value']
     line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
     
     all_lines5.append(y_data.values)  # 각 시점에서의 데이터들을 저장 
     start_time_list.append(start_time) 
     end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines5 = pd.DataFrame(all_lines5)
data5 = all_lines5.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data5, axis=0)
std_values = np.nanstd(data5, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:     
     plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:     
     all_lines5.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl') 
     df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')

# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
    # 선택한 이벤트
EVTtype = 'EVT6'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines5 = [] 

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
     selected_event_time = row['EVT_time']
     
     # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출 
     start_time = selected_event_time - 5
     end_time = selected_event_time + 10 
     filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]
     
     # 시간을 조정하여 데이터 시점을 맞춤 
     filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고  
     filtered_data['time'] -= selected_event_time 
     
     # lineplot 그리기 (투명도를 조절하여 녹색으로 표시) 
     x_data = filtered_data['time'] 
     y_data = filtered_data['value']
     line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
     
     all_lines5.append(y_data.values)  # 각 시점에서의 데이터들을 저장 
     start_time_list.append(start_time) 
     end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines5 = pd.DataFrame(all_lines5)
data5 = all_lines5.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data5, axis=0)
std_values = np.nanstd(data5, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:     
     plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:     
     all_lines5.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl') 
     df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')

# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
    # 선택한 이벤트
EVTtype = 'EVT7'
selected_event = 1.0 # '1' means the onset time of the event.

# 선택한 이벤트에 해당하는 행 필터링
selected_events_data = df_EVT[df_EVT[EVTtype] == selected_event].copy() #SettingWithCopyWarning 참고 
selected_events_data['EVT_time'] = list((selected_events_data.index+1)/FPS)

# 그래프 생성
ax=plt.figure(figsize=(10, 6))


# 각 이벤트에 대해 데이터를 추출하고 lineplot으로 그림
all_lines5 = [] 

# start_time과 end_time을 저장할 변수 생성 
start_time_list = []
end_time_list = []

# 모든 line들을 저장하기 위한 리스트
for index, row in selected_events_data.iterrows():
     selected_event_time = row['EVT_time']
     
     # 이벤트 발생 시간을 기준으로 2초 전부터 3초 후까지의 데이터 추출 
     start_time = selected_event_time - 5
     end_time = selected_event_time + 10 
     filtered_data = GCaMP_signal[(GCaMP_signal['time'] >= start_time) & (GCaMP_signal['time'] <= end_time)]
     
     # 시간을 조정하여 데이터 시점을 맞춤 
     filtered_data = filtered_data.copy() #SettingWithCopyWarning 참고  
     filtered_data['time'] -= selected_event_time 
     
     # lineplot 그리기 (투명도를 조절하여 녹색으로 표시) 
     x_data = filtered_data['time'] 
     y_data = filtered_data['value']
     line, = plt.plot(x_data, y_data, color='green', alpha=0.1)
     
     all_lines5.append(y_data.values)  # 각 시점에서의 데이터들을 저장 
     start_time_list.append(start_time) 
     end_time_list.append(end_time)

# 모든 시점에서의 데이터들을 2차원 배열로 변환
all_lines5 = pd.DataFrame(all_lines5)
data5 = all_lines5.to_numpy()

# start, end 시간을 2차원 배열로 변환 
df_TimeWindow = pd.DataFrame({'start' : start_time_list,
                             'end' : end_time_list})

# 각 시점에서의 데이터들의 평균값 계산
# mean_values = all_lines.mean(axis=0, numeric_only=False)
mean_values = np.nanmean(data5, axis=0)
std_values = np.nanstd(data5, axis=0)

min_length = min(len(mean_values), len(std_values))
x_data = (np.linspace(0, 15, min_length))-5

# 그래프 제목과 레이블 추가
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')

# 범례 추가
# plt.legend()
plt.grid(True)
plt.xlim(-5, 10)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

plt.plot(x_data, mean_values, color='green', label='Mean Value', linewidth=4)

if SavePlots == True:     
     plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+individual.png")

if SaveData==True:     
     all_lines5.to_pickle(f'Data_Extracted_signal_in_{EVTtype}.pkl') 
     df_TimeWindow.to_pickle(f'Data_TimeWindow_for_{EVTtype}.pkl')

# 그래프 출력
plt.show()

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
plt.title(Animal_ID+'_'+Session+' '+EVTtype)
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
AUC = []
ind1 = np.where((np.array(x_data)>-2) & (np.array(x_data)>2))

def aucfunction(x):
    return auc(x_data[ind1], x[ind1])

AUC = np.apply_along_axis(aucfunction, axis=1, arr=data5)
np.nanmean(AUC)


# Run a two-sample T-test
# t_stat,p_val = stats.ttest_ind(np.mean(data5, axis=0)[ind1],
#                                np.mean(data5, axis=0)[ind2], equal_var=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       4 def aucfunction(x):
#       5     return auc(x_data[ind1], x[ind1])
# ----> 7 AUC = np.apply_along_axis(aucfunction, axis=1, arr=data5)
#       8 np.nanmean(AUC)
#
# File c:\Users\YGKim_IBS\anaconda3\Lib\site-packages\numpy\lib\shape_base.py:379, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     375 except StopIteration:
#     376     raise ValueError(
#     377         'Cannot apply_along_axis when any iteration dimensions are 0'
#     378     ) from None
# --> 379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     385 buff = zeros(inarr_view.shape[:-1] + res.shape, res.dtype)
#
# Cell In[28], line 5, in aucfunction(x)
#       4 def aucfunction(x):
# ----> 5     return auc(x_data[ind1], x[ind1])
#
# NameError: name 'auc' is not defined

# %%
# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot each time-series
# for i in range(data.shape[0]):
    # plt.plot(data[i, :], alpha=0.5, label=f'Series {i+1}')

# Plot the mean line
plt.plot(x_data,mean_values, color='g', linewidth=2, label='Mean')

# Plot the standard deviation area
plt.fill_between(
    x_data,
    mean_values - std_values,
    mean_values + std_values,
    color='gray',
    alpha=0.3,
    label='SD'
)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
# plt.title(f'Epoch Averaging {EVTtype}')
plt.legend()
plt.grid()
plt.xlim(-4,8)
plt.ylim(-3, 6)
plt.axvline(x=0, color = 'red', linestyle = '--', linewidth = 1.0)

if SavePlots == True:
    plt.savefig(f"Plot_Epoch_averaging_{EVTtype}_Mean+SD.png")

# Show the plot
plt.show()

# %%
range(len(EVTn))

# %%
EVTn = ['EVT1', 'EVT2', 'EVT3', 'EVT4', 'EVT5']
EVTname = ['Nose-to-Nose', 'Nose-to-Body','Nose-to-Anogenital', 'Approaching-or-Following', 'Body-to-Nose']

EVT_list = []
Point_list = []

for i in range(len(EVTn)): 

    df = pd.read_pickle('Data_Extracted_signal_in_EVT' + str(i+1) + '.pkl')

    globals()['mean_EVT' + str(i+1)] = np.array(df.mean())
    globals()['sem_EVT' + str(i+1)] = np.array(df.sem())

    x_data = (np.linspace(0, 15, 15259))-5

    indice = np.min(np.where(x_data >= 0.5))
    globals()['point_EVT' + str(i+1)] = df.iloc[:, indice]
    x = EVTname[i] 
    EVTnamelist =  list(np.repeat(x, df.iloc[:, indice].shape[0], axis=0))
    Pointlist = list(df.iloc[:, indice])

    EVT_list += EVTnamelist
    Point_list += Pointlist

    print(globals()['point_EVT' + str(i+1)].mean())

df_point_name = pd.DataFrame({'dF/F_@_500ms': Point_list, 
                         'EVT_name': EVT_list})

model = ols("Q('dF/F_@_500ms') ~ C(EVT_name)", df_point_name).fit()
anova_lm(model)

ax = sns.boxplot(data=df_point_name, x='EVT_name', y='dF/F_@_500ms')
ax.set_xticklabels("")
ax.set_xlabel("")
ax.set_ylabel("GCaMP dF/F at 0.5 sec (%)")
ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(bottom=False)
# Out:
# 2.8321647664210245
# 3.0101244961504965
# 2.6843719821514207
# -0.32204796613586467
# 0.8750790444987288

# %%
model = ols("Q('dF/F_@_500ms') ~ C(EVT_name)", df_point_name).fit()
print(anova_lm(model))
from statsmodels.sandbox.stats.multicomp import MultiComparison
comp = MultiComparison(df_point_name['dF/F_@_500ms'], df_point_name['EVT_name'])
tbl, a1, a2 = comp.allpairtest(ttest_ind, method= "bonf", )
print(tbl)
tbl2 = comp.tukeyhsd()
print(tbl2.summary())

# %%
# AUC = []
# ind1 = np.where((np.array(x_data)>-0.5) & (np.array(x_data)>1.5))

# def aucfunction(x):
#     return auc(x_data[ind1], x[ind1])

# AUC = np.apply_along_axis(aucfunction, axis=1, arr=data5)
# np.nanmean(AUC)

# %%
# 그래프 생성
ax=plt.figure(figsize=(6, 6))

x_data = (np.linspace(0, 15, len(mean_EVT1)))-5

for EVT in EVTn: 
    indice = np.where((np.array(x_data)>-0.5) & (np.array(x_data)>1.5))
    print(simps(x = x_data[indice], y = globals()['mean_'+str(EVT)][indice]))
    line, = plt.plot(x_data, globals()['mean_'+str(EVT)])
    plt.fill_between(x_data, 
                     globals()['mean_'+str(EVT)] - globals()['sem_'+str(EVT)], 
                     globals()['mean_'+str(EVT)] + globals()['sem_'+str(EVT)],
                     color='grey', 
                     alpha=0.06)

# Add labels and legend
plt.xlabel('Time (sec)')
plt.ylabel('GCaMP dF/F (%)')
# plt.title(f'Epoch Averaging {EVTtype}')
# plt.legend(['Nose-to-Nose', 'Nose-to-Body','Nose-to-Anogenital', 'Approaching-or-Following', 'Body-to-Nose'], 
#            loc='lower right',
#            bbox_to_anchor=(1, 1))
# plt.grid()
plt.xlim(-0.5,1.5)
plt.ylim(-1, 4)
plt.axvline(x=0, color='grey', linestyle='--')
plt.axhline(y=0, color='grey', linestyle='--')

plt.show()
