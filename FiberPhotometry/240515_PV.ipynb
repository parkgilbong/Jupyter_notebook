# %%
# pip install reportlab
# pip install tdt
# pip install opencv-python

# %% [markdown]
# ### 1. FP data preprocessing

# %%
import os   # import os module
import FPFunctions # import User-defined function
import FileFunctions # import User-defined function
import ReportGeneration # import User-defined function
import VideoFunctions # import User-defined function

# %%
Raw_data_path =  r'D:\DataAtCSBD\FiberPhotometry\TDT_Tank' #The folder where the TDT tanks are saved
Recorded_date = '240515' #The date of the recording
# Data_folder_path = 'G06_005-250114-150521' #The original folder name generated by TDT Synapse

Base_folder = r'D:\DataAtCSBD\FiberPhotometry\ProcessedData' #The folder where the processed data will be saved
Batch_folder = '240515_PV' 
# Animal_ID = 'B6_M_G06_005'
# Session = 'HA'

# %%
Datafolder_list = ['PV-Cre-240515-144159', 'PV-Cre-240515-150021', 'PV-Cre-240515-152508',
                'PV-Cre-240515-154824', 'PV-Cre-240515-160405', 'PV-Cre-240515-161919',
                'PV-Cre-240515-163743', 'PV-Cre-240515-165241', 'PV-Cre-240515-170739',
                'PV-Cre-240515-172646', 'PV-Cre-240515-174133', 'PV-Cre-240515-175631',
                'PV-Cre-240515-181950', 'PV-Cre-240515-183507', 'PV-Cre-240515-185001',
                'PV-Cre-240515-190940', 'PV-Cre-240515-192425', 'PV-Cre-240515-194129',
                'PV-Cre-240515-200619', 'PV-Cre-240515-202110', 'PV-Cre-240515-203541']
Animal_ID_list = ['PV_F_G01_001', 'PV_F_G01_002', 'PV_F_G01_003', 'PV_F_G01_004', 'PV_F_G02_001', 'PV_F_G02_002', 'PV_F_G02_003']
print(Animal_ID_list)
session_list = ['EE', 'SE', 'SS']

# %%
for i, folder in enumerate(Datafolder_list):
                TDT_Tanks_path = os.path.join(Raw_data_path, Recorded_date, folder)
                FPFunctions.FP_preprocessing_1ch(Tank_path=TDT_Tanks_path, 
                                Dest_folder = os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3],'Preprocessing'), 
                                FPS=32, 
                                Rec_duration=600)
                
                image_paths = [os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3], 'Preprocessing', 'Plot_Raw_signal_465.png'),
                                os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3], 'Preprocessing', 'Plot_Denoised_signals.png'), 
                                os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3], 'Preprocessing', 'Plot_405_465_correlation.png'), 
                                os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3], 'Preprocessing', 'Plot_465_dFF.png')]

                comments = ["Figure1. Raw signals",
                            "Figure2. Denoised signals",
                            "Figure3. Correlation between 405 and 465",
                            "Figure4. 465 dFF"]

                ReportGeneration.FP_preprocessing(output_path=os.path.join(Base_folder, Batch_folder, Animal_ID_list[i//3], session_list[i%3]), 
                                                title=f'{Animal_ID_list[i//3]}_{session_list[i%3]}', 
                                                image_paths=image_paths, 
                                                comments=comments)

# %% [markdown]
# ### 2. Peak Analysis for FP signals

# %%
import os   # import os module
import FPFunctions # import User-defined function
import FileFunctions # import User-defined function

# %%
root_folder = r"D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV"
sub_folder_list = FileFunctions.Grab_folder_names_in_folder(root_folder)
sub_folder_list1 = ['EE', 'SE', 'SS'] #The list of session names
print(sub_folder_list)
# Out:
# ['PV_F_G01_001', 'PV_F_G01_002', 'PV_F_G01_003', 'PV_F_G01_004', 'PV_F_G02_001', 'PV_F_G02_002', 'PV_F_G02_003']

# %%
for sub_folder in sub_folder_list:
    for sub_folder1 in sub_folder_list1:
        destfolder = os.path.join(root_folder, sub_folder, sub_folder1)
        FileFunctions.Set_WD(destfolder)
        FPFunctions.Peak_Analysis(pkl_path=os.path.join(destfolder, 'Preprocessing', 'Final_table_raw_trace.pkl'), 
                                prominence_thres= 2, 
                                amplitude_thres= 4,
                                FPS= 32, 
                                pre_window_len= 3, 
                                post_window_len= 3, 
                                SavePlots = False, 
                                SaveData = False, 
                                SaveVideos= True,
                                video_path=os.path.join(destfolder, f'{sub_folder}_{sub_folder1}.avi'))
        # VideoFunctions.Generate_montage(input_folder=os.path.join(destfolder, 'Peak_Analysis', 'spike_detection'),
        #                                 output_filename='Motatge_spikes.mp4',
        #                                 rows=3,
        #                                 cols=5,
        #                                 frame_rate=25,
        #                                 duration=6,
        #                                 codec='mp4v',
        #                                 popups=[('Firing', 3 , 2)],
        #                                 scale_factor = 0.5)
# Out:
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\EE.
# 53 possible peaks detected in the signal
# 1 peaks detected with amplitude threshold
# Number of peaks detected: 1
# Mean amplitude of peaks: 4.1963280338549644
# Mean latency of peaks: 1.7596415648071684
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\SE.
# 37 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_001\SS.
# 26 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\EE.
# 82 possible peaks detected in the signal
# 19 peaks detected with amplitude threshold
# Number of peaks detected: 19
# Mean amplitude of peaks: 5.385607885747311
# Mean latency of peaks: 1.4467244173812908
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\SE.
# 83 possible peaks detected in the signal
# 10 peaks detected with amplitude threshold
# Number of peaks detected: 10
# Mean amplitude of peaks: 5.156188587465204
# Mean latency of peaks: 1.2409896711802149
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_002\SS.
# 100 possible peaks detected in the signal
# 11 peaks detected with amplitude threshold
# Number of peaks detected: 11
# Mean amplitude of peaks: 4.98682055853175
# Mean latency of peaks: 1.476168581385707
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\EE.
# 200 possible peaks detected in the signal
# 103 peaks detected with amplitude threshold
# Number of peaks detected: 103
# Mean amplitude of peaks: 6.291333363347812
# Mean latency of peaks: 1.1073420454259761
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\SE.
# 163 possible peaks detected in the signal
# 90 peaks detected with amplitude threshold
# Number of peaks detected: 90
# Mean amplitude of peaks: 6.759241441518916
# Mean latency of peaks: 1.253583505594995
# Error: Could not read frame 19200.
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_003\SS.
# 187 possible peaks detected in the signal
# 103 peaks detected with amplitude threshold
# Number of peaks detected: 103
# Mean amplitude of peaks: 6.517681340806244
# Mean latency of peaks: 1.1577634067476428
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\EE.
# 62 possible peaks detected in the signal
# 2 peaks detected with amplitude threshold
# Number of peaks detected: 2
# Mean amplitude of peaks: 4.2127296930871765
# Mean latency of peaks: 1.324646373507079
# Video slices extraction completed.
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\SE.
# 58 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G01_004\SS.
# 44 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\EE.
# 22 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\SE.
# 8 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_001\SS.
# 12 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\EE.
# No possible peaks detected in the signal
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\SE.
# 1 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_002\SS.
# No possible peaks detected in the signal
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\EE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\EE.
# No possible peaks detected in the signal
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\SE already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\SE.
# 1 possible peaks detected in the signal
# No peaks detected with amplitude threshold
# Directory D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\SS already exists.
# The working directory is set to D:\DataAtCSBD\FiberPhotometry\ProcessedData\240515_PV\PV_F_G02_003\SS.
# 3 possible peaks detected in the signal
# No peaks detected with amplitude threshold

# %% [markdown]
# ### 3. Epoch Analysis

# %%
import FileFunctions
import FPFunctions
import os

root_folder = r"D:\DataAtCSBD\FiberPhotometry\ProcessedData"
Batch_folder = '241211_B6'
Animal_ID = 'B6_M_G06_001'
Session = 'SE'

FileFunctions.Set_WD(os.path.join(root_folder, Batch_folder, Animal_ID, Session))

FPFunctions.Epoch_Analysis_3EVT(pkl_path=os.path.join(root_folder, Batch_folder, Animal_ID, Session, 'Preprocessing', 'Final_table_raw_trace.pkl'),
                        evt_path='Data_DLC_30.csv',
                        FPS=25,
                        Rec_duration=594,
                        SavePlots=False,
                        SaveData=False,
                        PRE_TIME=2,
                        POST_TIME=5)

# %%
root_folder = r"D:\DataAtCSBD\FiberPhotometry\ProcessedData"
Batch_folder = '241211_B6'
Animal_ID = 'B6_M_G07_005'
Session = 'EE'

FileFunctions.Set_WD(os.path.join(root_folder, Batch_folder, Animal_ID, Session))

FPFunctions.Epoch_Analysis_2EVT(pkl_path=os.path.join(root_folder, Batch_folder, Animal_ID, Session, 'Preprocessing', 'Final_table_raw_trace.pkl'),
                        evt_path='Data_DLC.csv',
                        FPS=25,
                        Rec_duration=600,
                        SavePlots=True,
                        SaveData=True,
                        PRE_TIME=2,
                        POST_TIME=5)
