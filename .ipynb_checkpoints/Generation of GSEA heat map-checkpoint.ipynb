# %% [markdown]
# # Generation of GSEA heat map

# %%
library(dplyr)

# %% [markdown]
# ## 폴더 안의 파일명 얻기
# ### GSEA 결과를 가지고 clustering analysis를 진행하여 총 12개의 cluster들을 얻었음. 이들 가운데 trained group에서 control group에 비해 up-regulation된 것을 *Enriched* folder에, 반대로 trained group에서 control group보다 down-regulation된 것을 *Deprived* folder로 명명

# %%
EnrichedInTraining_dir <- list.files(path = "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Enriched", full.names=TRUE)
EnrichedInControl_dir <- list.files(path = "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived", full.names=TRUE)
print(EnrichedInTraining_dir)
print(EnrichedInControl_dir)
# Out:
# [1] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Enriched/Cluster01.txt"
# [2] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Enriched/Cluster02.txt"
# [3] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Enriched/Cluster03.txt"
# [1] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster01.txt"
# [2] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster02.txt"
# [3] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster03.txt"
# [4] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster04.txt"
# [5] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster05.txt"
# [6] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster06.txt"
# [7] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster07.txt"
# [8] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster08.txt"
# [9] "C:/users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Deprived/Cluster09.txt"

# %% [markdown]
# ## 각 GSEA pair (Control-Trained)의 GSEA 결과를 Load

# %%
GSEA.UL <- read.delim("C:/Users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/GSEA, Raw_24H_UL.txt", sep="\t", header = T, stringsAsFactors = F)
GSEA.DL <- read.delim("C:/Users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/GSEA, Raw_24H_DL.txt", sep="\t", header = T, stringsAsFactors = F)
GSEA.OL <- read.delim("C:/Users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/GSEA, Raw_24H_OL.txt", sep="\t", header = T, stringsAsFactors = F)

# %%
dim(GSEA.DL)
dim(GSEA.UL)
dim(GSEA.OL)
# Out:
# [1] 2309   11
# [1] 2309   11
# [1] 2309   11

# %% [markdown]
# ## 불러온 GSEA 결과 엿보기

# %%
head(GSEA.DL)
head(GSEA.UL)
head(GSEA.OL)
# Out:
#   NAME
# 1 GO_BLOOD_MICROPARTICLE
# 2 GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION
# 3 GO_REGULATION_OF_WOUND_HEALING
# 4 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX
# 5 GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT
# 6 GO_INFLAMMATORY_RESPONSE
#   GS.br..follow.link.to.MSigDB                   GS.DETAILS  SIZE ES
# 1 GO_BLOOD_MICROPARTICLE                         Details ... 46   0.7105887
# 2 GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION        Details ... 81   0.5867403
# 3 GO_REGULATION_OF_WOUND_HEALING                 Details ... 31   0.6917205
# 4 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX          Details ... 64   0.5921182
# 5 GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT Details ... 16   0.8071039
# 6 GO_INFLAMMATORY_RESPONSE                       Details ... 51   0.6137181
#   NES      NOM.p.val FDR.q.val   FWER.p.val RANK.AT.MAX
# 1 2.385417 0         0.000000000 0.000      338
# 2 2.157102 0         0.003303327 0.006      596
# 3 2.107708 0         0.004039901 0.011      686
# 4 2.089420 0         0.004946524 0.018      870
# 5 2.088291 0         0.003957219 0.018      594
# 6 2.085647 0         0.003671486 0.020      569
#   LEADING.EDGE
# 1 tags=43%, list=8%, signal=47%
# 2 tags=42%, list=14%, signal=48%
# 3 tags=45%, list=17%, signal=54%
# 4 tags=55%, list=21%, signal=68%
# 5 tags=75%, list=14%, signal=87%
# 6 tags=41%, list=14%, signal=47%
#   NAME
# 1 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX
# 2 GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION
# 3 GO_MULTICELLULAR_ORGANISMAL_MACROMOLECULE_METABOLIC_PROCESS
# 4 GO_EXTRACELLULAR_MATRIX
# 5 GO_MULTICELLULAR_ORGANISM_METABOLIC_PROCESS
# 6 GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT
#   GS.br..follow.link.to.MSigDB                                GS.DETAILS  SIZE
# 1 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX                       Details ... 64
# 2 GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION                     Details ... 81
# 3 GO_MULTICELLULAR_ORGANISMAL_MACROMOLECULE_METABOLIC_PROCESS Details ... 18
# 4 GO_EXTRACELLULAR_MATRIX                                     Details ... 83
# 5 GO_MULTICELLULAR_ORGANISM_METABOLIC_PROCESS                 Details ... 19
# 6 GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT              Details ... 16
#   ES        NES      NOM.p.val FDR.q.val   FWER.p.val RANK.AT.MAX
# 1 0.6061036 2.150003 0         0.004563797 0.005      561
# 2 0.5796539 2.108616 0         0.003663566 0.008      631
# 3 0.7636614 2.098522 0         0.003676237 0.012      631
# 4 0.5667232 2.066041 0         0.007334331 0.032      561
# 5 0.7598928 2.043858 0         0.009884111 0.053      631
# 6 0.7748652 2.043438 0         0.008545915 0.055      840
#   LEADING.EDGE
# 1 tags=44%, list=14%, signal=50%
# 2 tags=43%, list=15%, signal=50%
# 3 tags=61%, list=15%, signal=72%
# 4 tags=40%, list=14%, signal=45%
# 5 tags=58%, list=15%, signal=68%
# 6 tags=88%, list=20%, signal=109%
#   NAME
# 1 GO_SNRNA_METABOLIC_PROCESS
# 2 GO_NEGATIVE_REGULATION_OF_DNA_METABOLIC_PROCESS
# 3 GO_MEIOTIC_CELL_CYCLE
# 4 GO_DNA_TEMPLATED_TRANSCRIPTION_ELONGATION
# 5 GO_NCRNA_TRANSCRIPTION
# 6 GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER
#   GS.br..follow.link.to.MSigDB                                GS.DETAILS  SIZE
# 1 GO_SNRNA_METABOLIC_PROCESS                                  Details ... 24
# 2 GO_NEGATIVE_REGULATION_OF_DNA_METABOLIC_PROCESS             Details ... 30
# 3 GO_MEIOTIC_CELL_CYCLE                                       Details ... 32
# 4 GO_DNA_TEMPLATED_TRANSCRIPTION_ELONGATION                   Details ... 32
# 5 GO_NCRNA_TRANSCRIPTION                                      Details ... 23
# 6 GO_TRANSCRIPTION_ELONGATION_FROM_RNA_POLYMERASE_II_PROMOTER Details ... 30
#   ES        NES      NOM.p.val   FDR.q.val FWER.p.val RANK.AT.MAX
# 1 0.6756252 1.932008 0.000000000 0.2230512 0.205      972
# 2 0.5730839 1.739064 0.003502627 1.0000000 0.963      908
# 3 0.5594117 1.730824 0.005235602 1.0000000 0.973      838
# 4 0.5713344 1.722959 0.000000000 0.9427758 0.977      972
# 5 0.6054039 1.719714 0.005067567 0.7884907 0.982      972
# 6 0.5704447 1.706589 0.003623189 0.7566872 0.989      972
#   LEADING.EDGE
# 1 tags=67%, list=23%, signal=87%
# 2 tags=50%, list=22%, signal=64%
# 3 tags=47%, list=20%, signal=58%
# 4 tags=53%, list=23%, signal=69%
# 5 tags=52%, list=23%, signal=68%
# 6 tags=53%, list=23%, signal=69%

# %% [markdown]
# ## GSEA 결과에서 필요한 것들만 취함

# %%
GSEA.DL  <-  select(GSEA.DL, c(NAME,SIZE, ES, NES, NOM.p.val, FDR.q.val ))
GSEA.UL  <-  select(GSEA.UL, c(NAME,SIZE, ES, NES, NOM.p.val, FDR.q.val ))
GSEA.OL  <-  select(GSEA.OL, c(NAME,SIZE, ES, NES, NOM.p.val, FDR.q.val ))

# %%
head(GSEA.UL)
# Out:
#   NAME                                                        SIZE ES
# 1 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX                       64   0.6061036
# 2 GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION                     81   0.5796539
# 3 GO_MULTICELLULAR_ORGANISMAL_MACROMOLECULE_METABOLIC_PROCESS 18   0.7636614
# 4 GO_EXTRACELLULAR_MATRIX                                     83   0.5667232
# 5 GO_MULTICELLULAR_ORGANISM_METABOLIC_PROCESS                 19   0.7598928
# 6 GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT              16   0.7748652
#   NES      NOM.p.val FDR.q.val
# 1 2.150003 0         0.004563797
# 2 2.108616 0         0.003663566
# 3 2.098522 0         0.003676237
# 4 2.066041 0         0.007334331
# 5 2.043858 0         0.009884111
# 6 2.043438 0         0.008545915

# %% [markdown]
# ## merge 함수를 이용하기 위해 df 이름 변경

# %%
names(GSEA.UL)  <- c("NAME", "UL.SIZE", "UL.ES", "UL.NES", "UL.p.val", "UL.q.val")
names(GSEA.DL)  <- c("NAME", "DL.SIZE", "DL.ES", "DL.NES", "DL.p.val", "DL.q.val")
names(GSEA.OL)  <- c("NAME", "OL.SIZE", "OL.ES", "OL.NES", "OL.p.val", "OL.q.val")

# %% [markdown]
# ## Gene-set NAME으로 합쳐서 master.df를 생성

# %%
master.df  <-  merge(GSEA.DL, GSEA.UL,by= "NAME")
master.df  <-  merge(master.df, GSEA.OL, by = "NAME")

# %% [markdown]
# ## master.df에 대한 summary

# %%
dim(master.df)
head(master.df)
summary(master.df)
# Out:
# [1] 2309   16
#   NAME                               DL.SIZE DL.ES      DL.NES     DL.p.val
# 1 GO_3_5_EXONUCLEASE_ACTIVITY        15      -0.2260609 -0.6056082 0.9458333
# 2 GO_4_IRON_4_SULFUR_CLUSTER_BINDING 16       0.4447620  1.1661059 0.2846715
# 3 GO_ACETYL_COA_METABOLIC_PROCESS    15      -0.1822362 -0.4965963 0.9855372
# 4 GO_ACETYLTRANSFERASE_ACTIVITY      25       0.2932916  0.8607133 0.6850829
# 5 GO_ACETYLTRANSFERASE_COMPLEX       21      -0.3739510 -1.0697901 0.3685345
# 6 GO_ACID_SECRETION                  33      -0.2438500 -0.7845336 0.8218263
#   DL.q.val  UL.SIZE UL.ES      UL.NES     UL.p.val   UL.q.val  OL.SIZE
# 1 1.0000000 15      -0.3048619 -0.8479007 0.69099754 0.9242768 15
# 2 0.6517217 16      -0.4268038 -1.2132324 0.23291140 0.6344746 16
# 3 1.0000000 15       0.2817319  0.7355507 0.83278143 0.9979415 15
# 4 0.9735227 25       0.3841609  1.1499107 0.27922080 0.6893120 25
# 5 0.9635347 21       0.3223746  0.9236013 0.56073210 0.9368089 21
# 6 1.0000000 33       0.4579068  1.4114778 0.06329114 0.3644461 33
#   OL.ES      OL.NES    OL.p.val   OL.q.val
# 1  0.4998676  1.285202 0.15696649 0.8157840
# 2  0.5305798  1.356912 0.12110092 0.8692402
# 3  0.2588075  0.661730 0.88868610 1.0000000
# 4  0.5242034  1.531332 0.02852050 0.7739853
# 5  0.5468623  1.514237 0.03860294 0.7657767
# 6 -0.3495904 -1.118172 0.28306264 0.6206894
#      NAME              DL.SIZE          DL.ES             DL.NES
#  Length:2309        Min.   : 15.0   Min.   :-0.6724   Min.   :-1.9349
#  Class :character   1st Qu.: 23.0   1st Qu.:-0.2372   1st Qu.:-0.8350
#  Mode  :character   Median : 38.0   Median : 0.2419   Median : 0.8439
#                     Mean   : 74.5   Mean   : 0.1100   Mean   : 0.3531
#                     3rd Qu.: 83.0   3rd Qu.: 0.3444   3rd Qu.: 1.1130
#                     Max.   :490.0   Max.   : 0.8071   Max.   : 2.3854
#     DL.p.val         DL.q.val         UL.SIZE          UL.ES
#  Min.   :0.0000   Min.   :0.0000   Min.   : 15.0   Min.   :-0.74426
#  1st Qu.:0.1628   1st Qu.:0.7113   1st Qu.: 23.0   1st Qu.:-0.25750
#  Median :0.4501   Median :0.9222   Median : 38.0   Median : 0.23150
#  Mean   :0.4695   Mean   :0.8097   Mean   : 74.5   Mean   : 0.08203
#  3rd Qu.:0.7606   3rd Qu.:1.0000   3rd Qu.: 83.0   3rd Qu.: 0.33314
#  Max.   :1.0000   Max.   :1.0000   Max.   :490.0   Max.   : 0.77487
#      UL.NES           UL.p.val         UL.q.val           OL.SIZE
#  Min.   :-2.0997   Min.   :0.0000   Min.   :0.003664   Min.   : 15.0
#  1st Qu.:-0.9531   1st Qu.:0.1463   1st Qu.:0.618507   1st Qu.: 23.0
#  Median : 0.7982   Median :0.3972   Median :0.793574   Median : 38.0
#  Mean   : 0.2333   Mean   :0.4337   Mean   :0.741511   Mean   : 74.5
#  3rd Qu.: 1.0978   3rd Qu.:0.7113   3rd Qu.:0.951064   3rd Qu.: 83.0
#  Max.   : 2.1500   Max.   :1.0000   Max.   :1.000000   Max.   :490.0
#      OL.ES             OL.NES            OL.p.val         OL.q.val
#  Min.   :-0.7243   Min.   :-2.14245   Min.   :0.0000   Min.   :0.01139
#  1st Qu.:-0.2950   1st Qu.:-1.02904   1st Qu.:0.1769   1st Qu.:0.71914
#  Median : 0.2002   Median : 0.69569   Median :0.4419   Median :0.96874
#  Mean   : 0.0219   Mean   : 0.04748   Mean   :0.4668   Mean   :0.82989
#  3rd Qu.: 0.3037   3rd Qu.: 0.99108   3rd Qu.:0.7540   3rd Qu.:1.00000
#  Max.   : 0.6756   Max.   : 1.93201   Max.   :1.0000   Max.   :1.00000

# %% [markdown]
# ## 추출할 protein list 불러오기. 여기서 불러올 list는 clustering analysis에서 이미 정한 cluster list 임.

# %%
Deprived.list <-c(t(read.delim("C:/Users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Merged_enriched in control.txt", sep="\t", header = FALSE, stringsAsFactors = FALSE)))

# %% [markdown]
# ## 아래 처럼 extraction 할 수 있지만 cluster list에서 정한 순서가 무너짐. 따라서 다른 방법으로

# %%
head(master.df[master.df$NAME %in% Deprived.list,])
dim(master.df[master.df$NAME %in% Deprived.list,])
# Out:
#     NAME                    DL.SIZE DL.ES     DL.NES    DL.p.val   DL.q.val
# 55  GO_AMIDE_TRANSPORT       23     0.4109725 1.1751381 0.24581006 0.645314000
# 77  GO_ANION_TRANSPORT      165     0.2371668 0.9595882 0.55705710 0.887607630
# 120 GO_BASEMENT_MEMBRANE     34     0.6295993 1.9458153 0.00000000 0.009069514
# 127 GO_BIOLOGICAL_ADHESION  259     0.3827280 1.6344279 0.00000000 0.185622290
# 131 GO_BODY_FLUID_SECRETION  22     0.3036342 0.8662260 0.64545450 0.976578200
# 132 GO_BONE_DEVELOPMENT      34     0.4971595 1.5718436 0.02735043 0.235534440
#     UL.SIZE UL.ES     UL.NES   UL.p.val    UL.q.val   OL.SIZE OL.ES
# 55   23     0.4143116 1.162739 0.285942500 0.67869365  23      0.4491404
# 77  165     0.3965820 1.592326 0.001295337 0.22052893 165     -0.2153858
# 120  34     0.6126484 1.914993 0.000000000 0.03751384  34     -0.2274824
# 127 259     0.3605262 1.530630 0.000000000 0.27687755 259      0.2380188
# 131  22     0.6100841 1.742265 0.013289036 0.12981868  22     -0.3765206
# 132  34     0.5412725 1.670445 0.003236246 0.16680890  34      0.2948329
#     OL.NES     OL.p.val  OL.q.val
# 55   1.2783340 0.1551433 0.8255184
# 77  -0.9185167 0.7002457 0.8995712
# 120 -0.7335303 0.8951049 1.0000000
# 127  1.0214375 0.3788820 1.0000000
# 131 -1.1271930 0.2933619 0.6188940
# 132  0.9223552 0.5795053 1.0000000
# [1] 99 16

# %%
extracted.list <- list()
for (i in 1:length(Deprived.list)) {
    extracted.list[[i]] <- master.df[master.df$NAME==Deprived.list[i], ]
}
total.list <- do.call(rbind, extracted.list)

# %%
total.list
# Out:
#      NAME                                                               DL.SIZE
# 188  GO_CELL_CELL_ADHESION_VIA_PLASMA_MEMBRANE_ADHESION_MOLECULES        41
# 131  GO_BODY_FLUID_SECRETION                                             22
# 711  GO_INTEGRIN_BINDING                                                 36
# 183  GO_CELL_ADHESION_MOLECULE_BINDING                                   66
# 187  GO_CELL_CELL_ADHESION                                              137
# 136  GO_CADHERIN_BINDING                                                 15
# 1671 GO_REGULATION_OF_COAGULATION                                        22
# 1676 GO_REGULATION_OF_CYTOKINE_PRODUCTION                                90
# 1067 GO_NEGATIVE_REGULATION_OF_RESPONSE_TO_EXTERNAL_STIMULUS             69
# 1677 GO_REGULATION_OF_CYTOKINE_SECRETION                                 17
# 1000 GO_NEGATIVE_REGULATION_OF_CYTOKINE_PRODUCTION                       33
# 670  GO_HOMOPHILIC_CELL_ADHESION_VIA_PLASMA_MEMBRANE_ADHESION_MOLECULES  31
# 213  GO_CELL_MATRIX_ADHESION                                             43
# 1931 GO_REGULATION_OF_WOUND_HEALING                                      31
# 1606 GO_REGULATION_OF_BODY_FLUID_LEVELS                                 150
# 652  GO_HEMOSTASIS                                                      107
# 1445 GO_POSITIVE_REGULATION_OF_RESPONSE_TO_WOUNDING                      26
# 1085 GO_NEGATIVE_REGULATION_OF_WOUND_HEALING                             19
# 2014 GO_RESPONSE_TO_WOUNDING                                            175
# 2306 GO_WOUND_HEALING                                                   140
# 998  GO_NEGATIVE_REGULATION_OF_COAGULATION                               15
# 1070 GO_NEGATIVE_REGULATION_OF_RESPONSE_TO_WOUNDING                      38
# 1741 GO_REGULATION_OF_INFLAMMATORY_RESPONSE                              55
# 1295 GO_PLATELET_ACTIVATION                                              61
# 671  GO_HOMOTYPIC_CELL_CELL_ADHESION                                     23
# 127  GO_BIOLOGICAL_ADHESION                                             259
# 1875 GO_REGULATION_OF_RESPONSE_TO_WOUNDING                               91
# 1003 GO_NEGATIVE_REGULATION_OF_DEFENSE_RESPONSE                          31
# 1296 GO_PLATELET_AGGREGATION                                             20
# 1041 GO_NEGATIVE_REGULATION_OF_MULTICELLULAR_ORGANISMAL_PROCESS         221
# ...  ...                                                                ...
# 282  GO_CELLULAR_RESPONSE_TO_KETONE                                      26
# 262  GO_CELLULAR_RESPONSE_TO_ACID_CHEMICAL                               49
# 297  GO_CELLULAR_RESPONSE_TO_STEROID_HORMONE_STIMULUS                    48
# 295  GO_CELLULAR_RESPONSE_TO_RETINOIC_ACID                               16
# 875  GO_MIDBRAIN_DEVELOPMENT                                             34
# 579  GO_FOREBRAIN_DEVELOPMENT                                            95
# 645  GO_HEAD_DEVELOPMENT                                                231
# 310  GO_CEREBRAL_CORTEX_DEVELOPMENT                                      36
# 2164 GO_SUBSTANTIA_NIGRA_DEVELOPMENT                                     29
# 1088 GO_NEURAL_NUCLEUS_DEVELOPMENT                                       35
# 1232 GO_PALLIUM_DEVELOPMENT                                              49
# 2188 GO_TELENCEPHALON_DEVELOPMENT                                        67
# 904  GO_MONOCARBOXYLIC_ACID_TRANSPORT                                    38
# 566  GO_FATTY_ACID_TRANSPORT                                             21
# 77   GO_ANION_TRANSPORT                                                 165
# 1198 GO_ORGANIC_ACID_TRANSPORT                                           92
# 800  GO_LONG_CHAIN_FATTY_ACID_TRANSPORT                                  17
# 1200 GO_ORGANIC_ANION_TRANSPORT                                         131
# 316  GO_CHLORIDE_CHANNEL_COMPLEX                                         16
# 710  GO_INSULIN_SECRETION                                                15
# 1534 GO_PROTEIN_SECRETION                                                34
# 55   GO_AMIDE_TRANSPORT                                                  23
# 1243 GO_PEPTIDE_TRANSPORT                                                19
# 675  GO_HORMONE_TRANSPORT                                                19
# 1242 GO_PEPTIDE_SECRETION                                                17
# 120  GO_BASEMENT_MEMBRANE                                                34
# 550  GO_EXTRACELLULAR_MATRIX_STRUCTURAL_CONSTITUENT                      16
# 546  GO_EXTRACELLULAR_MATRIX                                             83
# 1551 GO_PROTEINACEOUS_EXTRACELLULAR_MATRIX                               64
# 548  GO_EXTRACELLULAR_MATRIX_COMPONENT                                   41
#      DL.ES      DL.NES     DL.p.val    DL.q.val    UL.SIZE UL.ES
# 188   0.5427666  1.7324628 0.001773050 0.090831140  41      0.4197522
# 131   0.3036342  0.8662260 0.645454500 0.976578200  22      0.6100841
# 711   0.5995305  1.8794464 0.000000000 0.021376822  36      0.4758654
# 183   0.4617453  1.6174140 0.003311258 0.205177890  66      0.3265267
# 187   0.4008795  1.5881649 0.000000000 0.226502330 137      0.3078215
# 136  -0.3367573 -0.9063198 0.566893400 1.000000000  15     -0.2791559
# 1671  0.7212508  1.9999550 0.000000000 0.005665143  22      0.3495581
# 1676  0.4123381  1.5418367 0.004983389 0.242486000  90      0.2136824
# 1067  0.5469394  1.9358144 0.000000000 0.010156603  69      0.3779483
# 1677  0.5890468  1.5512380 0.020793950 0.245514930  17      0.5154645
# 1000  0.5725675  1.7629725 0.001724138 0.078851310  33      0.3623640
# 670   0.5306294  1.6096362 0.008833922 0.208664580  31      0.3115439
# 213   0.4574590  1.4797366 0.033687940 0.307575850  43      0.4930046
# 1931  0.6917205  2.1077075 0.000000000 0.004039901  31      0.3465442
# 1606  0.4370967  1.7452860 0.000000000 0.087853450 150      0.3124911
# 652   0.4791082  1.8436335 0.000000000 0.033697380 107      0.2594112
# 1445  0.5213158  1.5368391 0.027072757 0.246301310  26      0.2771081
# 1085  0.7278734  2.0197900 0.000000000 0.004844337  19      0.3386358
# 2014  0.4306710  1.7523305 0.000000000 0.082508825 175      0.2720259
# 2306  0.4436918  1.7527865 0.000000000 0.084127900 140      0.2502041
# 998   0.7729211  1.9698073 0.000000000 0.006903767  15      0.3975421
# 1070  0.6340926  1.9896989 0.000000000 0.006110918  38      0.4310041
# 1741  0.4714708  1.6411923 0.008561644 0.176978720  55      0.3931280
# 1295  0.5046573  1.7636249 0.001680672 0.080363850  61      0.3175413
# 671   0.5392539  1.5575129 0.035055350 0.241978240  23     -0.1998778
# 127   0.3827280  1.6344279 0.000000000 0.185622290 259      0.3605262
# 1875  0.5179193  1.9257565 0.000000000 0.011610004  91      0.3617470
# 1003  0.5072634  1.5493017 0.034172660 0.242513790  31      0.5315818
# 1296  0.6189820  1.6771299 0.003759399 0.141311260  20      0.1881144
# 1041  0.3705027  1.5641918 0.000000000 0.240638720 221      0.2863832
# ...  ...        ...        ...         ...         ...     ...
# 282  -0.2921608 -0.8795202 0.656542060 1.000000000  26     0.5431232
# 262   0.3514939  1.1789488 0.219594600 0.640805360  49     0.5181681
# 297   0.3976957  1.3297721 0.089947090 0.465591220  48     0.4822565
# 295   0.5471651  1.4351908 0.062271062 0.351907250  16     0.6248711
# 875   0.6344534  1.9570915 0.000000000 0.007778847  34     0.5454788
# 579   0.4126082  1.5480362 0.006655574 0.240663290  95     0.4196269
# 645   0.3525197  1.4846038 0.001459854 0.304952920 231     0.3760972
# 310   0.4936008  1.5528180 0.020583190 0.244567230  36     0.4840361
# 2164  0.6892906  2.0760000 0.000000000 0.004108144  29     0.5411567
# 1088  0.6680772  2.0576138 0.000000000 0.004657754  35     0.5162795
# 1232  0.5002626  1.6530321 0.003355705 0.168086800  49     0.4356425
# 2188  0.4185941  1.4726558 0.018771332 0.309753060  67     0.4448415
# 904   0.2347551  0.7425936 0.898066760 1.000000000  38     0.5854032
# 566   0.2647476  0.7283328 0.854166700 1.000000000  21     0.6712039
# 77    0.2371668  0.9595882 0.557057100 0.887607630 165     0.3965820
# 1198  0.2417057  0.9087722 0.642414870 0.944349050  92     0.4717295
# 800  -0.2939272 -0.7961640 0.755102040 1.000000000  17     0.6513492
# 1200  0.2487774  0.9821954 0.511326850 0.861817500 131     0.4374835
# 316   0.2881611  0.7359151 0.835106400 1.000000000  16     0.3740995
# 710   0.4007475  1.0465776 0.418772550 0.788491960  15     0.4709170
# 1534  0.3469165  1.0774773 0.333901200 0.753606600  34     0.4068630
# 55    0.4109725  1.1751381 0.245810060 0.645314000  23     0.4143116
# 1243  0.4576457  1.2280886 0.214669050 0.567019460  19     0.4572255
# 675   0.3370293  0.9275652 0.548623860 0.919953350  19     0.3875515
# 1242  0.3966583  1.0495838 0.400749060 0.788284600  17     0.3944456
# 120   0.6295993  1.9458153 0.000000000 0.009069514  34     0.6126484
# 550   0.8071039  2.0882910 0.000000000 0.003957219  16     0.7748652
# 546   0.5509853  2.0128493 0.000000000 0.004980112  83     0.5667232
# 1551  0.5921182  2.0894196 0.000000000 0.004946524  64     0.6061036
# 548   0.5952646  1.9500333 0.001584786 0.008652650  41     0.5954897
#      UL.NES     UL.p.val    UL.q.val    OL.SIZE OL.ES      OL.NES
# 188   1.3750635 0.068078670 0.4114600    41      0.4265583  1.3739624
# 131   1.7422651 0.013289036 0.1298187    22     -0.3765206 -1.1271930
# 711   1.5290594 0.021523180 0.2779119    36      0.3245222  1.0146892
# 183   1.1497654 0.253541080 0.6883745    66     -0.2392364 -0.8936651
# 187   1.2238399 0.123552120 0.6171510   137      0.2266902  0.8999043
# 136  -0.7626350 0.774271850 0.9605474    15     -0.6548426 -1.6947143
# 1671  0.9834198 0.481605350 0.8802576    22      0.3615517  1.0485960
# 1676  0.7948968 0.849931800 0.9862120    90      0.2954229  1.0992745
# 1067  1.3667579 0.057101026 0.4175024    69      0.3197070  1.1258917
# 1677  1.3735577 0.105982910 0.4081892    17      0.3364735  0.8956848
# 1000  1.1302810 0.278662400 0.7149433    33      0.3109752  0.9804991
# 670   0.9556084 0.549918200 0.8986905    31      0.4267031  1.3151951
# 213   1.6262249 0.004800000 0.1976232    43      0.2244056  0.7374182
# 1931  1.0514643 0.407348250 0.8029317    31      0.4366878  1.3093840
# 1606  1.2329525 0.105263160 0.6009742   150      0.2750187  1.1021252
# 652   0.9990153 0.459422300 0.8583319   107      0.2555907  0.9725668
# 1445  0.8274719 0.733871000 0.9908722    26      0.5529333  1.6153955
# 1085  0.9139684 0.600000000 0.9431745    19      0.4774954  1.2846563
# 2014  1.1107011 0.241379300 0.7394314   175      0.2533146  1.0371069
# 2306  0.9903640 0.479539630 0.8720782   140      0.2395855  0.9507870
# 998   1.0269825 0.430485760 0.8281624    15      0.5167902  1.3155904
# 1070  1.3873072 0.069841270 0.3936069    38      0.3314464  1.0617894
# 1741  1.3634370 0.066568050 0.4195037    55      0.3353285  1.1608624
# 1295  1.1077721 0.297935100 0.7440366    61      0.2210276  0.7750546
# 671  -0.6176733 0.937007840 0.9990147    23     -0.2437108 -0.6993497
# 127   1.5306304 0.000000000 0.2768775   259      0.2380188  1.0214375
# 1875  1.3561053 0.042134833 0.4292364    91      0.3311129  1.2546301
# 1003  1.6201774 0.008090615 0.1994819    31      0.2836333  0.8639750
# 1296  0.5234473 0.979831930 1.0000000    20     -0.2301510 -0.6605715
# 1041  1.2001483 0.108312346 0.6421543   221      0.1894363  0.7994029
# ...  ...        ...         ...         ...     ...        ...
# 282  1.6200185  0.009569378 0.196883400  26      0.2726487  0.7943340
# 262  1.7394370  0.001461988 0.125948790  49      0.2767386  0.9157761
# 297  1.6046691  0.007824726 0.214259640  48      0.3133892  1.0360858
# 295  1.6773560  0.003466205 0.169649050  16      0.4101432  1.0618547
# 875  1.7337573  0.004587156 0.126566840  34      0.3109850  0.9625722
# 579  1.5802039  0.001353180 0.237449700  95      0.2604192  0.9907758
# 645  1.5659186  0.001245330 0.243999910 231     -0.1839830 -0.8185160
# 310  1.5285913  0.031201247 0.276387160  36      0.2553615  0.7999875
# 2164 1.6429970  0.003120125 0.179716800  29      0.2886571  0.8545370
# 1088 1.6284068  0.012500000 0.196479010  35      0.2889778  0.8978919
# 1232 1.4494548  0.041284405 0.344775940  49      0.3292733  1.0907834
# 2188 1.5849378  0.010189229 0.229793100  67      0.2761639  0.9719449
# 904  1.8746027  0.000000000 0.051463420  38     -0.2514972 -0.8349133
# 566  1.8770318  0.000000000 0.053692255  21      0.3446924  0.9545590
# 77   1.5923259  0.001295337 0.220528930 165     -0.2153858 -0.9185167
# 1198 1.7525749  0.000000000 0.119231960  92      0.2510898  0.9340158
# 800  1.7335858  0.011589404 0.123005690  17     -0.3257371 -0.8939745
# 1200 1.7232088  0.000000000 0.130228650 131      0.2440602  0.9520936
# 316  0.9824921  0.486348120 0.880971400  16     -0.5609981 -1.5226990
# 710  1.2193282  0.236331570 0.619354900  15      0.3551604  0.9241943
# 1534 1.2750379  0.146645860 0.554899040  34      0.3755997  1.1697854
# 55   1.1627393  0.285942500 0.678693650  23      0.4491404  1.2783340
# 1243 1.2471929  0.185064940 0.585452740  19      0.4041897  1.1123224
# 675  1.0674247  0.373083470 0.796299460  19     -0.3110236 -0.8814771
# 1242 1.0659052  0.367857130 0.794012100  17      0.3764723  0.9938520
# 120  1.9149929  0.000000000 0.037513837  34     -0.2274824 -0.7335303
# 550  2.0434375  0.000000000 0.008545915  16      0.4532361  1.1967559
# 546  2.0660408  0.000000000 0.007334331  83      0.2771655  1.0249317
# 1551 2.1500032  0.000000000 0.004563797  64      0.3011818  1.0620915
# 548  1.9172823  0.000000000 0.040570780  41     -0.3116861 -1.0358058
#      OL.p.val    OL.q.val
# 188  0.051785715 0.8422076
# 131  0.293361870 0.6188940
# 711  0.412811400 1.0000000
# 183  0.676886800 0.9238829
# 187  0.716193700 1.0000000
# 136  0.011764706 0.1721360
# 1671 0.377622370 1.0000000
# 1676 0.294702000 0.9778774
# 1067 0.256666660 0.9802895
# 1677 0.625222000 1.0000000
# 1000 0.489130440 1.0000000
# 670  0.109756100 0.8338097
# 213  0.878632500 1.0000000
# 1931 0.120689650 0.8102055
# 1606 0.252336440 0.9775708
# 652  0.518394650 1.0000000
# 1445 0.007017544 0.6382577
# 1085 0.136363640 0.8136535
# 2014 0.386292850 1.0000000
# 2306 0.568503900 1.0000000
# 998  0.140449430 0.8378754
# 1070 0.381481470 0.9964661
# 1741 0.198653190 0.9617197
# 1295 0.866115700 1.0000000
# 671  0.903529400 1.0000000
# 127  0.378882000 1.0000000
# 1875 0.115702480 0.8688049
# 1003 0.673721300 1.0000000
# 1296 0.928571400 1.0000000
# 1041 0.941176500 1.0000000
# ...  ...         ...
# 282  0.79757786  1.0000000
# 262  0.61139894  1.0000000
# 297  0.40378007  1.0000000
# 295  0.38095240  0.9984846
# 875  0.53228620  1.0000000
# 579  0.48287672  1.0000000
# 645  0.95454544  0.9794751
# 310  0.79122806  1.0000000
# 2164 0.69006850  1.0000000
# 1088 0.61022925  1.0000000
# 1232 0.30639732  0.9765230
# 2188 0.52631580  1.0000000
# 904  0.77092510  0.9687053
# 566  0.51013510  1.0000000
# 77   0.70024570  0.8995712
# 1198 0.59324760  1.0000000
# 800  0.61036040  0.9267108
# 1200 0.53697747  1.0000000
# 316  0.02474227  0.2482158
# 710  0.57826890  1.0000000
# 1534 0.24333926  0.9446802
# 55   0.15514334  0.8255184
# 1243 0.29078013  0.9693898
# 675  0.65721040  0.9408780
# 1242 0.49090910  1.0000000
# 120  0.89510490  1.0000000
# 550  0.24953790  0.9407061
# 546  0.40163934  1.0000000
# 1551 0.33609270  0.9996578
# 548  0.37995338  0.7191403

# %% [markdown]
# ## 추출한 결과를 txt file로 저장

# %%
write.table(x = total.list, file = "~/Deprived_list.txt",quote = F, sep = "\t")
# Out:
# Warning message in file(file, ifelse(append, "a", "w")):
# "파일 'C:\Users\KimYG\Documents/Deprived_list.txt'를 여는데 실패했습니다: Permission denied"
# Error in file(file, ifelse(append, "a", "w")): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. write.table(x = total.list, file = "~/Deprived_list.txt", quote = F,
#  .     sep = "\t")
# 2. file(file, ifelse(append, "a", "w"))

# %% [markdown]
# ## 위와 같은 방식으로 Enriched list에 대한 분석을 진행

# %%
Enriched.list <-c(t(read.delim("C:/Users/KimYG/Experimental Data/Proteomics/GSEA/GSEA result_R/Merged_enriched in training.txt", sep="\t", header = FALSE, stringsAsFactors = FALSE)))

extracted.list2 <- list()
for (i in 1:length(Enriched.list)) {
    extracted.list2[[i]] <- master.df[master.df$NAME==Enriched.list[i], ]
}

total.list2 <- do.call(rbind, extracted.list2)
total.list2

write.table(total.list2, file = "~/Enriched_list.txt", quote = F, sep = "\t")
# Out:
#      NAME                                                             DL.SIZE
# 1002 GO_NEGATIVE_REGULATION_OF_CYTOSKELETON_ORGANIZATION               74
# 1851 GO_REGULATION_OF_PROTEIN_POLYMERIZATION                           78
# 1062 GO_NEGATIVE_REGULATION_OF_PROTEIN_POLYMERIZATION                  25
# 1434 GO_POSITIVE_REGULATION_OF_PROTEIN_POLYMERIZATION                  38
# 1773 GO_REGULATION_OF_MICROTUBULE_POLYMERIZATION_OR_DEPOLYMERIZATION   59
# 1841 GO_REGULATION_OF_PROTEIN_COMPLEX_ASSEMBLY                        154
# 1306 GO_POSITIVE_REGULATION_OF_ACTIN_FILAMENT_POLYMERIZATION           30
# 988  GO_NEGATIVE_REGULATION_OF_CELL_PROJECTION_ORGANIZATION            58
# 402  GO_CYTOSKELETAL_PROTEIN_BINDING                                  342
# 1842 GO_REGULATION_OF_PROTEIN_COMPLEX_DISASSEMBLY                      74
# 1680 GO_REGULATION_OF_CYTOSKELETON_ORGANIZATION                       182
# 1654 GO_REGULATION_OF_CELLULAR_COMPONENT_SIZE                         134
# 1772 GO_REGULATION_OF_MICROTUBULE_POLYMERIZATION                       16
# 1589 GO_REGULATION_OF_ACTIN_FILAMENT_DEPOLYMERIZATION                  20
# 993  GO_NEGATIVE_REGULATION_OF_CELLULAR_COMPONENT_ORGANIZATION        246
# 2260 GO_TUBULIN_BINDING                                               115
# 1590 GO_REGULATION_OF_ACTIN_FILAMENT_LENGTH                            66
# 1587 GO_REGULATION_OF_ACTIN_FILAMENT_BASED_PROCESS                    116
# 1058 GO_NEGATIVE_REGULATION_OF_PROTEIN_COMPLEX_DISASSEMBLY             54
# 125  GO_BETA_TUBULIN_BINDING                                           21
# 1057 GO_NEGATIVE_REGULATION_OF_PROTEIN_COMPLEX_ASSEMBLY                40
# 966  GO_NEGATIVE_REGULATION_OF_ACTIN_FILAMENT_POLYMERIZATION           17
# 10   GO_ACTIN_BINDING                                                 162
# 969  GO_NEGATIVE_REGULATION_OF_AXONOGENESIS                            22
# 1111 GO_NEUROTRANSMITTER_TRANSPORT                                     81
# 1801 GO_REGULATION_OF_NEUROTRANSMITTER_SECRETION                       29
# 144  GO_CALCIUM_ION_REGULATED_EXOCYTOSIS                               35
# 1102 GO_NEURON_PROJECTION                                             441
# 539  GO_EXOCYTIC_VESICLE_MEMBRANE                                      37
# 2176 GO_SYNAPSE_PART                                                  313
# 1905 GO_REGULATION_OF_SYNAPTIC_VESICLE_TRANSPORT                       19
# 1470 GO_POSTSYNAPSE                                                   183
# 1800 GO_REGULATION_OF_NEUROTRANSMITTER_LEVELS                          96
# 2110 GO_SITE_OF_POLARIZED_GROWTH                                       79
# 1480 GO_PRESYNAPTIC_PROCESS_INVOLVED_IN_SYNAPTIC_TRANSMISSION          60
# 2179 GO_SYNAPTIC_VESICLE_CYCLE                                         41
# 1107 GO_NEURON_PROJECTION_TERMINUS                                     65
# 2180 GO_SYNAPTIC_VESICLE_LOCALIZATION                                  52
# 223  GO_CELL_PROJECTION_PART                                          367
# 536  GO_EXCITATORY_SYNAPSE                                            105
# 411  GO_CYTOSOLIC_TRANSPORT                                           110
# 1711 GO_REGULATION_OF_EXOCYTOSIS                                       83
# 1477 GO_PRESYNAPSE                                                    163
# 2190 GO_TERMINAL_BOUTON                                                39
# 2173 GO_SYNAPSE                                                       376
# 1478 GO_PRESYNAPTIC_ACTIVE_ZONE                                        23
# 1919 GO_REGULATION_OF_TRANSPORTER_ACTIVITY                             79
# 1866 GO_REGULATION_OF_RELEASE_OF_SEQUESTERED_CALCIUM_ION_INTO_CYTOSOL  24
# 1316 GO_POSITIVE_REGULATION_OF_CALCIUM_ION_TRANSMEMBRANE_TRANSPORT     17
# 143  GO_CALCIUM_ION_IMPORT                                             20
# 1609 GO_REGULATION_OF_CALCIUM_ION_TRANSMEMBRANE_TRANSPORT              38
# 1081 GO_NEGATIVE_REGULATION_OF_TRANSPORTER_ACTIVITY                    26
# 406  GO_CYTOSOLIC_CALCIUM_ION_TRANSPORT                                18
# 1623 GO_REGULATION_OF_CATION_CHANNEL_ACTIVITY                          29
# 439  GO_DIVALENT_INORGANIC_CATION_HOMEOSTASIS                          93
# 1610 GO_REGULATION_OF_CALCIUM_ION_TRANSMEMBRANE_TRANSPORTER_ACTIVITY   28
# 1881 GO_REGULATION_OF_SEQUESTERING_OF_CALCIUM_ION                      33
# 1748 GO_REGULATION_OF_ION_HOMEOSTASIS                                  57
# 1031 GO_NEGATIVE_REGULATION_OF_ION_TRANSPORT                           40
#      DL.ES      DL.NES     DL.p.val    DL.q.val  UL.SIZE UL.ES      UL.NES
# 1002 -0.3237282 -1.2283025 0.117647060 0.8711609  74     -0.3458020 -1.4369226
# 1851 -0.4264867 -1.6504079 0.002427185 0.9075514  78     -0.4055061 -1.6873162
# 1062 -0.4850999 -1.4736377 0.054824560 0.7210470  25     -0.4596794 -1.4484608
# 1434 -0.3783029 -1.2775738 0.140589570 0.8407194  38     -0.4314673 -1.5233516
# 1773 -0.3986481 -1.4727296 0.036057692 0.7073930  59     -0.3850246 -1.4917018
# 1841 -0.2755970 -1.1780680 0.113960120 0.8847086 154     -0.2753369 -1.2579298
# 1306 -0.3542555 -1.1084784 0.293849650 0.9224700  30     -0.4502170 -1.5005978
# 988   0.3659701  1.2720602 0.117940200 0.5247463  58      0.3262860  1.1371984
# 402  -0.2778034 -1.3007312 0.000000000 0.8279700 342     -0.2901081 -1.4629441
# 1842 -0.3210331 -1.2420789 0.132275130 0.8512369  74     -0.3600044 -1.4492358
# 1680 -0.2590801 -1.1298099 0.188087780 0.9451029 182     -0.2675296 -1.2582253
# 1654 -0.2687511 -1.1167040 0.214285720 0.9537789 134     -0.2421123 -1.0937237
# 1772 -0.5887385 -1.5746082 0.030232558 0.6143454  16     -0.5303075 -1.5315989
# 1589 -0.3771330 -1.0692402 0.354485780 0.9591424  20     -0.2704853 -0.8127919
# 993   0.2408471  1.0253462 0.383582100 0.8222043 246      0.1981711  0.8309014
# 2260 -0.3157089 -1.3164395 0.052341600 0.8322388 115     -0.2701325 -1.1906123
# 1590 -0.3912049 -1.4628808 0.015306123 0.6870520  66     -0.3759038 -1.5084664
# 1587 -0.2723091 -1.1128426 0.215025900 0.9301417 116     -0.2575013 -1.1527693
# 1058 -0.3142081 -1.1323310 0.221461190 0.9377174  54     -0.2991325 -1.1422354
# 125  -0.4646513 -1.3241892 0.141906870 0.8515203  21     -0.4561633 -1.3652395
# 1057 -0.3968798 -1.3190427 0.096629210 0.8478033  40     -0.3746367 -1.3715341
# 966  -0.4074861 -1.1361263 0.302222220 0.9471225  17     -0.4149890 -1.1662673
# 10   -0.2655596 -1.1444463 0.136246790 0.9412479 162     -0.2798940 -1.2822634
# 969   0.4640236  1.3314054 0.127041740 0.4659999  22      0.4093634  1.1563936
# 1111 -0.2608093 -1.0177059 0.445876300 1.0000000  81      0.2558265  0.9392412
# 1801 -0.4115841 -1.2823961 0.130541880 0.8408008  29     -0.3079824 -1.0176643
# 144  -0.3551232 -1.1620342 0.218390810 0.9179626  35      0.2563759  0.8083531
# 1102 -0.2700836 -1.2919620 0.007168459 0.8522791 441     -0.2358274 -1.2086194
# 539   0.1913617  0.6039764 0.974533100 1.0000000  37     -0.3401802 -1.2034028
# 2176 -0.2820482 -1.3134998 0.006493507 0.8283426 313     -0.2372838 -1.1835800
# 1905 -0.3225547 -0.8981824 0.616033730 1.0000000  19     -0.3548888 -1.0645027
# 1470 -0.3264406 -1.4235898 0.000000000 0.7391569 183     -0.2922836 -1.3702554
# 1800 -0.3186657 -1.2731348 0.075520836 0.8316701  96     -0.1896547 -0.8079339
# 2110 -0.3538031 -1.3540714 0.036781610 0.9096740  79     -0.3206996 -1.3069970
# 1480 -0.3158118 -1.1448686 0.217391300 0.9439970  60     -0.2315742 -0.8919498
# 2179 -0.3489054 -1.1919369 0.177631570 0.9157868  41     -0.2511760 -0.9070892
# 1107 -0.4497625 -1.6778477 0.000000000 1.0000000  65     -0.4197160 -1.6917101
# 2180 -0.2957922 -1.0355232 0.375000000 1.0000000  52     -0.2639261 -1.0099812
# 223  -0.2896270 -1.3812057 0.000000000 0.8495848 367     -0.2402038 -1.2204376
# 536  -0.3702320 -1.5192600 0.002754821 0.7291635 105     -0.3110655 -1.3377182
# 411  -0.2874206 -1.1795876 0.127423820 0.8877736 110     -0.2551119 -1.1238552
# 1711 -0.2788370 -1.0829424 0.277500000 0.9612939  83     -0.2308622 -0.9746016
# 1477 -0.3129674 -1.3567631 0.025210084 0.9232325 163     -0.2485957 -1.1555321
# 2190 -0.5593808 -1.9348589 0.000000000 0.3504467  39     -0.5231525 -1.8824749
# 2173 -0.2505383 -1.1816142 0.065454540 0.9042068 376     -0.2077995 -1.0535656
# 1478 -0.5401103 -1.5828345 0.023148147 0.6351492  23     -0.2997213 -0.9340076
# 1919 -0.3857234 -1.5005736 0.014705882 0.7302877  79     -0.2846264 -1.1960970
# 1866 -0.4982946 -1.5281106 0.047727272 0.7103948  24     -0.5255363 -1.6494406
# 1316 -0.5647205 -1.5302380 0.049356222 0.7263884  17     -0.5391532 -1.5651547
# 143  -0.5164411 -1.4602343 0.075723834 0.6837192  20     -0.3750583 -1.1356796
# 1609 -0.4435523 -1.4712995 0.056872036 0.6969985  38     -0.4536725 -1.6456739
# 1081 -0.4900489 -1.4812107 0.031674210 0.7416048  26     -0.3070004 -0.9999903
# 406  -0.4708860 -1.2801310 0.185022030 0.8438454  18     -0.2501208 -0.7250893
# 1623 -0.5049106 -1.5777094 0.020316027 0.6290618  29     -0.4741615 -1.6044935
# 439  -0.3582005 -1.4233701 0.009925558 0.7264174  93     -0.4073968 -1.7269168
# 1610 -0.5275367 -1.6430926 0.016018307 0.8597318  28     -0.4801236 -1.6043055
# 1881 -0.4851503 -1.5937843 0.015118791 0.6480610  33     -0.4348679 -1.4764202
# 1748 -0.4101357 -1.4821494 0.026378896 0.7581942  57     -0.3081124 -1.1890241
# 1031 -0.4633884 -1.6039386 0.009708738 0.6307747  40     -0.3286147 -1.1644615
#      UL.p.val    UL.q.val  OL.SIZE OL.ES      OL.NES    OL.p.val    OL.q.val
# 1002 0.018691588 0.4239314  74     -0.4989593 -1.900013 0.000000000 0.07895413
# 1851 0.000000000 0.3327710  78     -0.5429397 -2.099096 0.000000000 0.01138741
# 1062 0.067010306 0.4203581  25     -0.6388799 -1.951121 0.002331002 0.05378865
# 1434 0.019662922 0.3663918  38     -0.5456324 -1.802011 0.000000000 0.12381253
# 1773 0.015873017 0.3673820  59     -0.4454423 -1.617682 0.006960557 0.21929080
# 1841 0.041493777 0.6152350 154     -0.3755991 -1.609673 0.000000000 0.21774100
# 1306 0.038356163 0.3644715  30     -0.5999886 -1.883548 0.002457002 0.08734546
# 988  0.243647230 0.7037388  58     -0.4468799 -1.588403 0.000000000 0.22288103
# 402  0.000000000 0.4086923 342     -0.3528041 -1.651320 0.000000000 0.21695897
# 1842 0.013201321 0.4232360  74     -0.4629906 -1.755387 0.000000000 0.13031371
# 1680 0.041322313 0.6175602 182     -0.3665021 -1.583262 0.000000000 0.22919036
# 1654 0.227848100 0.7145987 134     -0.3779411 -1.561489 0.000000000 0.23136187
# 1772 0.057471264 0.3685836  16     -0.7243345 -1.960525 0.002169197 0.05638817
# 1589 0.728155300 0.9495500  20     -0.5906756 -1.711360 0.008830022 0.16606390
# 993  0.864226700 0.9891281 246     -0.3548330 -1.605757 0.000000000 0.21344648
# 2260 0.123456790 0.6499502 115     -0.3816231 -1.568133 0.002652520 0.23718399
# 1590 0.009554140 0.3645679  66     -0.5496290 -2.040189 0.000000000 0.01954192
# 1587 0.154385970 0.6724450 116     -0.3773818 -1.519914 0.002770083 0.24885388
# 1058 0.227692300 0.6788390  54     -0.5088279 -1.821344 0.000000000 0.11615775
# 125  0.095238100 0.5309398  21     -0.5871819 -1.710298 0.004357298 0.16255645
# 1057 0.079772080 0.5289639  40     -0.5201902 -1.761930 0.004950495 0.13148226
# 966  0.235142110 0.6556910  17     -0.5898923 -1.628616 0.008714597 0.21150416
# 10   0.028571429 0.6132693 162     -0.3844135 -1.647922 0.000000000 0.20850869
# 969  0.288643540 0.6841959  22     -0.5347495 -1.557999 0.018912530 0.22632079
# 1111 0.584659930 0.9146031  81     -0.3988319 -1.532386 0.005012531 0.24079725
# 1801 0.404145100 0.7749006  29     -0.4901822 -1.567064 0.023584906 0.23321436
# 144  0.756965940 0.9940923  35     -0.5221711 -1.723875 0.002288329 0.15275410
# 1102 0.008620690 0.6388065 441     -0.3282316 -1.569259 0.000000000 0.23848980
# 539  0.191044780 0.6474167  37     -0.4579830 -1.563945 0.009661836 0.23000018
# 2176 0.040816326 0.6480508 313     -0.3895264 -1.791952 0.000000000 0.12377560
# 1905 0.357487920 0.7456619  19     -0.5379571 -1.520926 0.052995390 0.24921718
# 1470 0.017777778 0.5241861 183     -0.3689611 -1.615281 0.000000000 0.21989164
# 1800 0.887218060 0.9504685  96     -0.4045009 -1.608999 0.002427185 0.21520743
# 2110 0.040404040 0.5878178  79     -0.4565453 -1.763501 0.000000000 0.13481314
# 1480 0.700879750 0.8902774  60     -0.4625845 -1.668933 0.004819277 0.20123200
# 2179 0.612535600 0.8783451  41     -0.5220800 -1.789268 0.006944445 0.12122440
# 1107 0.000000000 0.3374871  65     -0.4704204 -1.756106 0.004866180 0.13425437
# 2180 0.397553500 0.7842829  52     -0.5129964 -1.802494 0.007389163 0.13126153
# 223  0.032258064 0.6387566 367     -0.3294293 -1.541255 0.000000000 0.23021048
# 536  0.035019454 0.5590366 105     -0.3950976 -1.569386 0.000000000 0.24157389
# 411  0.214285720 0.6892107 110     -0.4010854 -1.596308 0.004807693 0.21988802
# 1711 0.532467540 0.8283911  83     -0.4101662 -1.608425 0.000000000 0.21287125
# 1477 0.120833330 0.6657226 163     -0.4355003 -1.867216 0.000000000 0.08786933
# 2190 0.000000000 0.1985952  39     -0.6360403 -2.142447 0.000000000 0.01775018
# 2173 0.336000000 0.7506400 376     -0.3580076 -1.693490 0.000000000 0.16900463
# 1478 0.561224460 0.8581495  23     -0.6078233 -1.798936 0.000000000 0.12026434
# 1919 0.154605270 0.6527214  79     -0.4032176 -1.541771 0.011737090 0.23692448
# 1866 0.027227722 0.3380811  24     -0.5460182 -1.624512 0.013953488 0.21510160
# 1316 0.033898305 0.3533547  17     -0.6225269 -1.697708 0.006802721 0.17216256
# 143  0.276485800 0.6747178  20     -0.5473463 -1.547542 0.035320090 0.23160672
# 1609 0.008571428 0.3263228  38     -0.4870441 -1.650248 0.004555809 0.20897467
# 1081 0.450381670 0.7859231  26     -0.5118744 -1.565023 0.022624435 0.23395322
# 406  0.832098800 0.9737846  18     -0.5850154 -1.594750 0.018475750 0.21574287
# 1623 0.018421052 0.3363630  29     -0.5350709 -1.654839 0.004750594 0.21551079
# 439  0.003731343 0.2972447  93     -0.4194997 -1.660528 0.000000000 0.21051976
# 1610 0.018817205 0.3284240  28     -0.5022152 -1.574514 0.011061947 0.23500514
# 1881 0.032258064 0.3831209  33     -0.5765027 -1.869139 0.000000000 0.09393547
# 1748 0.161490680 0.6475237  57     -0.4238030 -1.524842 0.012077294 0.24929236
# 1031 0.232432430 0.6591398  40     -0.4806432 -1.633894 0.002277904 0.20692557
