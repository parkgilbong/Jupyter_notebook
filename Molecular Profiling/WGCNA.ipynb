# %% [markdown]
# # Load Mass data

# %%
load("~/Proteomics_whole.rda")
massdata <- Imported.data
head(massdata)
# Out:
#        Gene_name Ctrl_01H_1   Ctrl_01H_2  Ctrl_01H_3  DL_01H_1     DL_01H_2
# Q8BP71 Rbfox2    -0.001372884 -0.03255354  0.03638155 -0.039450985 -0.001388398
# Q9D7A8 Armc1      0.043063311 -0.01077864  0.03601730  0.034919143  0.001373960
# Q9QXG2 Chm        0.010935601 -0.01353600  0.04514682 -0.146510686 -0.064130217
# Q8R3F5 Mcat      -0.124033937 -0.04540889  0.04246268 -0.074890563  0.070141335
# Q3TVE3 S100a16   -0.140261030  0.05516122 -0.25111355 -0.008976283 -0.555901908
# P45952 Acadm      0.024352328 -0.05282601 -0.01932646  0.069974055 -0.074994177
#        DL_01H_3     UL_01h_1    UL_01H_2     UL_01H_3     ... Ctrl_24H_3
# Q8BP71 -0.044334151  0.01901486  0.010610083  0.060469650 ... -0.01654058
# Q9D7A8  0.005241369  0.03109326  0.071852975  0.012965687 ...  0.02769589
# Q9QXG2 -0.140147512 -0.11591854  0.007100808 -0.063179969 ... -0.14310740
# Q8R3F5 -0.009263490 -0.03984456 -0.104787985  0.029775237 ... -0.07484510
# ...

# %%
library(dplyr)

# %%
Ctrl <- select(massdata, c("Ctrl_24H_1", "Ctrl_24H_2", "Ctrl_24H_3"))
Trained <- select(massdata, c("OL_24H_1", "OL_24H_2", "OL_24H_3"))
Ctrl <- data.frame(2^(Ctrl))
Trained <- data.frame(2^(Trained))
head(Ctrl)
head(Trained)
# Out:
#        Ctrl_24H_1 Ctrl_24H_2 Ctrl_24H_3
# Q8BP71 1.0040274  1.0277463  0.9886004
# Q9D7A8 1.0239417  0.9721771  1.0193828
# Q9QXG2 1.0400564  0.9962471  0.9055666
# Q8R3F5 0.9822823  1.0891210  0.9494441
# Q3TVE3 1.0798209  0.9787711  0.9046864
# P45952 0.9735570  0.9783962  1.0243537
#        OL_24H_1  OL_24H_2  OL_24H_3
# Q8BP71 0.9944271 1.0001044 0.9669826
# Q9D7A8 0.9714853 0.9974934 1.0160284
# Q9QXG2 1.0713900 1.0326409 1.0344866
# Q8R3F5 0.9979275 0.9925673 0.9375344
# Q3TVE3 0.9431247 0.8964384 1.1798997
# P45952 1.0334252 1.0081514 0.9680067

# %%
rownames(Trained[apply(Trained, 1, mean)/apply(Ctrl, 1, mean)>=1.2, ])
Trained[apply(Trained, 1, mean)/apply(Ctrl, 1, mean)<=0.8, ]
# Out:
#  [1] "P84086"   "P37804"   "E9PUC5"   "F8WHQ1"   "Q3TU20"   "P28184"
#  [7] "Q9CPX6"   "O35843"   "Q3UIL6-2" "Q3TVW1"   "Q60598"   "Q8K2K6"
# [13] "Q3UYK2"   "Q6PE13"   "Q8BP27"   "P70429"   "Q8BHB9"   "Q545B6"
# [19] "Q02013"   "A8IK50"   "Q91ZZ3"   "O55042"   "Q8BYN3"   "Q8C8R3-7"
# [25] "D3Z4V2"   "Q3UMC8"   "P02802"
#        OL_24H_1  OL_24H_2  OL_24H_3
# Q1W5W7 1.1382070 0.7957411 0.8442938
# Q8QZX0 1.2107948 1.0046482 0.9345380
# Q68FM7 0.7315571 0.9177154 0.8838113
# Q9DCU2 0.8844343 0.9114193 0.9425621
# Q91X58 0.7467234 0.8821080 0.7476828
# Q8C622 0.8784137 0.7664571 0.6842647
# Q8BMI0 0.7875838 0.8419756 0.7912667
# F8WHD9 1.0602224 1.0205253 0.9091296
# Q99LC9 0.7509790 0.7496669 0.8632139
# Q8BVR6 0.8331757 0.8481975 0.8384576

# %%
DEPlist <- read.delim("clipboard", header=F)

# %%
DEPlist
# Out:
#    V1
# 1  Q78J03
# 2  Q8BXC6
# 3  Q8BX80
# 4  P11881-6
# 5  F7BNZ5
# 6  Q925N1
# 7  Q69ZS6
# 8  Q8C7M3
# 9  Q9CZJ2
# 10 E9PWI3
# 11 Q64332-2
# 12 Q3U2V3
# 13 Q61033
# 14 Q9ERE8
# 15 A2BDX0
# 16 Q8CCS2
# 17 Q3UYK2
# 18 Q6P9J5
# 19 P28481
# 20 Q9D8S9
# 21 Q64362
# 22 Q3UV17
# 23 B6ZHD1
# 24 Q8BP27
# 25 P28653
# 26 P07309
# 27 P84086
# 28 E9PUC5
# 29 F8WHQ1
# 30 Q9CPX6
# 31 Q3UIL6-2
# 32 Q60598
# 33 Q8K2K6
# 34 Q545B6
# 35 A8IK50
# 36 Q91ZZ3
# 37 O55042
# 38 D3Z4V2
# 39 Q3UMC8
# 40 Q68FM7
# 41 Q9DCU2
# 42 Q8C622
# 43 Q8BVR6

# %%
Turquoise  <- read.delim("clipboard", header = F)

# %%
Judge  <- DEPlist$V1 %in% Turquoise$V1
Judge
table(Judge)
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# Judge
# FALSE
#    43

# %%
DEPlist[Judge,]
# Out:
#  [1] Q3UYK2   Q8BP27   P84086   E9PUC5   F8WHQ1   Q9CPX6   Q3UIL6-2 Q60598
#  [9] Q8K2K6   Q545B6   A8IK50   Q91ZZ3   O55042   D3Z4V2   Q3UMC8
# 43 Levels: A2BDX0 A8IK50 B6ZHD1 D3Z4V2 E9PUC5 E9PWI3 F7BNZ5 F8WHQ1 ... Q9ERE8
